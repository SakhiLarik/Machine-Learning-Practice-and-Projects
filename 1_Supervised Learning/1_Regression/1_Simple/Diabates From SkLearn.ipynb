# %% [markdown]
# ##### Import Sklearn Library, Dataset from sklearn

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes

# %% [markdown]
# #### load data from library and store it into x and y

# %%
X, y = load_diabetes(return_X_y=True)

# %%
print(X[0])
# Columns are Age, Sex, BMI and S1 to S6
# Out:
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
print(X.shape)
# Out:
# (442, 10)

# %%
print(y.shape)
# Out:
# (442,)

# %%
print(y[0:4])
# Out:
# [151.  75. 141. 206.]

# %% [markdown]
# ##### Machine Learning Begins Here
# 1. Think a bit about the relationship between the data and the regression target. Linear
# regression predicts relationships between feature X and target variable y.
#
# 2. Next, select a portion of this dataset to plot by arranging it into a new array using numpy's
# newaxis function. We are going to use linear regression to generate a line between values in
# this data, according to a pattern it determines.

# %%
X = X[:, np.newaxis, 2]
print(X.shape)
# Out:
# (442, 1)

# %% [markdown]
# 3. Now that you have data ready to be plotted, you can see if a machine can help determine a logical
# split between the numbers in this dataset. To do this, you need to split both the data (X) and the
# target (y) into test and training sets. Scikit-learn has a straightforward way to do this; you can split
# your test data at a given point.

# %%
from sklearn import model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y,test_size=0.2)

# %% [markdown]
# The test_size parameter determines the proportion of the original dataset to include in the test split. In this case, we’ve set it to 0.2, meaning 20% of the data will be used for the test set, and the remaining 80% for the training set.
#
# While train_test_split from Scikit-Learn is a popular choice for dividing datasets, there are other libraries like Pandas and NumPy that offer alternative methods.

# %% [markdown]
# 4. Now you are ready to train your model! Load up the linear regression model and train it with your X
# and y training sets using model.fit():

# %% [markdown]
# The modal has to go throug two phases in order to build a machine learning prediction in Sklearn
# 1. Create a modal and
# 2. Assign data to model to learn from it.
#
# All modals are python objects, to let model to learn we use .fit(X,y)
# Here I am doing linear regression so I have to import and fit the linear regression modal

# %%
myModal = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# 5. Then, create a prediction using test data, using the function predict() . This will be used to
# draw the line between data group

# %%
y_Predict = myModal.predict(X_test)
y_Predict
# Out:
# array([130.43958174, 118.7761147 ,  77.95398005,  98.36504738,
#        184.8690946 , 194.58865047, 124.60784822, 188.75691695,
#        158.62629376, 157.65433817,  97.39309179, 125.57980381,
#        217.91558455, 146.96282672, 157.65433817, 169.31780521,
#        233.46687394, 111.97242559, 124.60784822, 111.97242559,
#        147.9347823 , 137.24327085, 191.67278371, 203.33625075,
#        131.41153733, 163.48607169, 144.04695996, 134.32740409,
#        147.9347823 , 114.88829235, 139.18718202, 142.10304878,
#        126.55175939, 136.27131526, 104.1967809 ,  99.33700296,
#        107.11264766, 204.30820634, 145.01891554, 238.32665188,
#        183.89713902, 125.57980381, 189.72887254, 185.84105019,
#        123.63589263, 178.06540549, 125.57980381, 217.91558455,
#        155.710427  , 133.3554485 , 209.16798427, 187.78496136,
#        137.24327085, 162.51411611, 189.72887254, 181.95322784,
#        151.82260465, 200.42038399, 298.58789826, 264.56945272,
# ...

# %% [markdown]
# 6. Now it's time to show the data in a plot. Matplotlib is a very useful tool for this task. Create a
# scatterplot of all the X and y test data, and use the prediction to draw a line in the most
# appropriate place, between the model's data groupings

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_Predict, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %% [markdown]
# Think a bit about what's going on here. A straight line is running through many small dots of
# data, but what is it doing exactly? Can you see how you should be able to use this line to predict
# where a new, unseen data point should fit in relationship to the plot's y axis? Try to put into words
# the practical use of this model
